# %% [markdown]
# <a href="https://colab.research.google.com/github/khuloodnasher/POS_part_one/blob/main/POS_part_one.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
my_text = nlp('''I believe in giving people a voice because, at the end of the day, I believe in people. 
And as long as enough of us keep fighting for this, I believe that more people’s voices will eventually
 help us work through these issues together and write a new chapter in our history — where from all of
  our individual voices and perspectives, we can bring the world closer together.

''')


for token in my_text:
    print('Words is   : ' , token.text)
    print('POS is   : ' , token.pos ,'===',token.pos_  , '===', spacy.explain(token.pos_))
    print('Dep is   : ' , token.dep , '===',token.dep_, '===', spacy.explain(token.dep_))
    print('Tag is   : ' , token.tag , '===',token.tag_, '===', spacy.explain(token.tag_))
    print('-----------------------')
# Out:
# Words is   :  I
# POS is   :  95 === PRON === pronoun
# Dep is   :  429 === nsubj === nominal subject
# Tag is   :  13656873538139661788 === PRP === pronoun, personal
# -----------------------
# Words is   :  believe
# POS is   :  100 === VERB === verb
# Dep is   :  8206900633647566924 === ROOT === None
# Tag is   :  9188597074677201817 === VBP === verb, non-3rd person singular present
# -----------------------
# Words is   :  in
# POS is   :  85 === ADP === adposition
# Dep is   :  443 === prep === prepositional modifier
# Tag is   :  1292078113972184607 === IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :  giving
# POS is   :  100 === VERB === verb
# Dep is   :  438 === pcomp === complement of preposition
# Tag is   :  1534113631682161808 === VBG === verb, gerund or present participle
# -----------------------
# Words is   :  people
# POS is   :  92 === NOUN === noun
# Dep is   :  3965108062993911700 === dative === dative
# ...
